# %%
import numpy as np
import scipy.optimize as opt
import matplotlib.pylab as plt

x = np.linspace(-5, 5, 100)

x0 = 3.0
objective  = np.poly1d([3.0, -3.0, -6.0])
print(objective)

results = opt.minimize(objective, x0)
print("Solution: x=%f " % results.x)

plt.plot(x, objective(x))
plt.plot(results.x, objective(results.x),'ro')
plt.show()
# Out:
# 2
# 3 x - 3 x - 6
# Solution: x=0.500000

# %%
import numpy as np
import scipy.optimize as opt
import matplotlib.pylab as plt

x = np.linspace(-5, 5, 100)

x0 = 3.0
objective  = np.poly1d([4.0, -5.0, -5.0, 2.73, -6.0])
print(objective)

results = opt.minimize(objective, x0)
print("Solution: x=%f " % results.x)

plt.plot(x, objective(x))
plt.plot(results.x, objective(results.x),'ro')
plt.show()
# Out:
# 4     3     2
# 4 x - 5 x - 5 x + 2.73 x - 6
# Solution: x=1.314269
