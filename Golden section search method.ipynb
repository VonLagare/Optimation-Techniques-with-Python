# %%
def gs(x , y ):
    ratio = 0.618
    a = ratio * ( y - x  )
    x1 = x  + a
    x2 = y - a 
    print(x1,x2 , a)

    iterations = 0 
    while True  :
        if y - x <= 0.001:
            break
        iterations += 1 
        if x1 > x2 :
            y = x1
            a = ratio * (y - x)
            x1 = x + a
            x2 = y-a
        else :
            x= x2
            a = ratio * (y -x )
            x1 = x + d
            x2 = y-d 
        print(iterations, x2,x1,y ,x )

gs(-200,300)
# Out:
# 109.0 -9.0 309.0
# 1 -81.96199999999999 -9.038000000000011 109.0 -200
# 2 -127.052516 -81.98548400000001 -9.038000000000011 -200
# 3 -154.91845488799999 -127.06702911200001 -81.98548400000001 -200
# 4 -172.139605120784 -154.92742399121602 -127.06702911200001 -200
# 5 -182.78227596464453 -172.1451480265715 -154.92742399121602 -200
# 6 -189.3594465461503 -182.78570148042118 -172.1451480265715 -200
# 7 -193.42413796552088 -189.3615635149003 -182.78570148042118 -200
# 8 -195.9361172626919 -193.4254462522084 -189.3615635149003 -200
# 9 -197.4885204683436 -195.93692578386478 -193.4254462522084 -200
# 10 -198.44790564943634 -197.48902013442844 -195.93692578386478 -200
# 11 -199.04080569135166 -198.44821444307678 -197.48902013442844 -200
# 12 -199.40721791725534 -199.04099652582144 -198.44821444307678 -200
# 13 -199.63366067286378 -199.40733585295766 -199.04099652582144 -200
# 14 -199.77360229582982 -199.63373355712784 -199.40733585295766 -200
# ...
