# %% [markdown]
# #Module 2 Practical Quiz#

# %% [markdown]
# 1. x3 -3x +2 interval (-3,3)

# %%
import numpy as np
import scipy.optimize as opt
import matplotlib.pylab as plt

x = np.linspace(-3 , 3, 100)

x0 = 2.0
objective = np.poly1d([1.0, 0.0, -3.0, 2])
print(objective)

results = opt.minimize(objective, x0)
print("Solution: x=%f" % results.x)

plt.plot(x,objective(x))
plt.plot(results.x, objective(results.x), 'ro')
plt.show
# Out:
# 3
# 1 x - 3 x + 2
# Solution: x=1.000000
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# 2. x4+3x3-9x2-23x-12 with interval (-5,5)

# %%
import numpy as np
import scipy.optimize as opt
import matplotlib.pylab as plt

x = np.linspace(-5 , 5, 100)

x0 = 5.0
objective = np.poly1d([1.0, 3.0, -9.0, -23.0, -12])
print(objective)

results = opt.minimize(objective, x0)
print("Solution: x=%f" % results.x)

plt.plot(x,objective(x))
plt.plot(results.x, objective(results.x), 'ro')
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-559417fb81de> in <module>
#       3 import matplotlib.pylab as plt
#       4
# ----> 5 x = np.linspace(6 , 4, -4)
#       6
#       7 x0 = 5.0
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# D:\Programs\Anaconda\lib\site-packages\numpy\core\function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     122
#     123     if num < 0:
# --> 124         raise ValueError("Number of samples, %s, must be non-negative." % num)
#     125     div = (num - 1) if endpoint else num
#     126
#
# ValueError: Number of samples, -4, must be non-negative.

# %% [markdown]
# 3. x3 -5x2 +3x+6 interval (-5,15)

# %%
import numpy as np
import scipy.optimize as opt
import matplotlib.pylab as plt

x = np.linspace(-5 , 15, 100)

x0 = 5.0
objective = np.poly1d([6.0, 4.0, -4.0])
print(objective)

results = opt.minimize(objective, x0)
print("Solution: x=%f" % results.x)

plt.plot(x,objective(x))
plt.plot(results.x, objective(results.x), 'ro')
plt.show
# Out:
# 2
# 6 x + 4 x - 4
# Solution: x=-0.333333
# <function matplotlib.pyplot.show(*args, **kw)>
